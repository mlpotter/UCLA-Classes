# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
LR_SGD = [0.01521,0.00526,0.00406,0.00356,0.00316,0.00284,0.00263,0.00239,0.00235,0.00218]
LR_Mom = [0.01987,0.00682,0.00258,0.00232,0.00107,0.00039,0.00056,0.00029,0.00032,0.00022]
SVM_SGD = [0.00942,0.00294,0.00202,0.00192,0.00156,0.00119,0.00111,0.00090,0.00088,0.00080]
SVM_Mom = [0.03018,0.01369,0.00702,0.00497,0.00346,0.00131,0.00156,0.00071,0.00046,0.00056]

# %%
filename = "SVM SGD vs SVM-0.9.png"
plt.figure(figsize=(15,15))
plt.plot(np.arange(10),SVM_SGD,linewidth=10)
plt.plot(np.arange(10),SVM_Mom,linewidth=10)
plt.xlabel("Epoch Number",fontsize=50)
plt.ylabel("Epoch Loss",fontsize=50)
plt.title(filename[:(len(filename)-4)],fontsize=50)
plt.legend(["SVM SGD","SVM SGD-0.9"],fontsize=50)
plt.xticks(ticks=np.arange(10),labels=np.arange(10)+1,fontsize=50); plt.yticks(fontsize=50)
plt.tight_layout()
#plt.savefig(filename)

# %%
filename = "LR SGD vs SGD-0.9.png"
plt.figure(figsize=(15,15))
plt.plot(np.arange(10),LR_SGD,linewidth=10)
plt.plot(np.arange(10),LR_Mom,linewidth=10)
plt.xlabel("Epoch Number",fontsize=50)
plt.ylabel("Epoch Loss",fontsize=50)
plt.title(filename[:(len(filename)-4)],fontsize=50)
plt.legend(["LR SGD","LR SGD-0.9"],fontsize=50)
plt.xticks(ticks=np.arange(10),labels=np.arange(10)+1,fontsize=50); plt.yticks(fontsize=50)
plt.tight_layout()
#plt.savefig(filename)
